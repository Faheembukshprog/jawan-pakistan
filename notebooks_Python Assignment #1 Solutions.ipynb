# %%
# Assignment #1 - Problem 1
# Print the given string in specific format

print("Twinkle, twinkle, little star,")
print("\tHow I wonder what you are!")
print("\t\tUp above the world so high,")
print("\t\tLike a diamond in the sky.")
print("Twinkle, twinkle, little star,")
print("\tHow I wonder what you are!")

# %%
# Assignment #1 - Problem 2
# Display the Python version currently in use

import sys

print("Python version:")
print(sys.version)

# %%
# Assignment #1 - Problem 3
# Display current date and time

import datetime

now = datetime.datetime.now()

print("Current date and time:")
print(now.strftime("%Y-%m-%d %H:%M:%S"))

# %%
# Assignment #1 - Problem 4
# Calculate area of a circle

from math import pi

radius = float(input("Enter radius of the circle: "))
area = pi * radius ** 2

print("Area of the circle is:", area)

# %%
# Assignment #1 - Problem 5
# Take first and last name and print in reverse order

first_name = input("Enter First Name: ")
last_name = input("Enter Last Name: ")

print("Reversed Name:", last_name, first_name)

# %%
# Assignment #1 - Problem 6
# Take two numbers and print their sum

num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

print("Sum:", num1 + num2)

# %%
# Assignment #1 - Problem 7
# Take marks of 5 subjects, calculate total, percentage and grade

m1 = float(input("Maths: "))
m2 = float(input("English: "))
m3 = float(input("Science: "))
m4 = float(input("History: "))
m5 = float(input("Urdu: "))

total = m1 + m2 + m3 + m4 + m5
percentage = (total / 500) * 100

if percentage >= 80:
    grade = "A+"
elif percentage >= 70:
    grade = "A"
elif percentage >= 60:
    grade = "B"
elif percentage >= 50:
    grade = "C"
else:
    grade = "Fail"

print("Total Marks:", total)
print("Percentage:", percentage)
print("Grade:", grade)

# %%
# Assignment #1 - Problem 8
# Check whether a number is Even or Odd

num = int(input("Enter a number: "))

if num % 2 == 0:
    print("Even Number")
else:
    print("Odd Number")

# %%
# Assignment #1 - Problem 9
# Calculate area of a triangle

base = float(input("Enter base: "))
height = float(input("Enter height: "))

area = (base * height) / 2

print("Area of triangle:", area)

# %%
# Assignment #1 - Problem 10
# Calculate future value using compound interest formula

p = float(input("Principal amount: "))
r = float(input("Interest rate: "))
t = int(input("Number of years: "))

amount = p * (1 + r/100) ** t

print("Total amount after", t, "years:", amount)
